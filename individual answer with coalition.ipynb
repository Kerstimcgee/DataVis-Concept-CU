# %% [markdown]
# New Data Pull
#
# You can tell which items hang together as a scale by
# looking at their prefix (e.g., boardrepresent). Scale scores are
# just an average score. It's also important that a single site's score gets
# compared to the average score for all respondents (across all sites).
#
# I think in general simple is better - a simple barchart will work for a broader
# range of data
