# %%
from os import path
fname = './CoalitionSurveyTesting2018.csv'

# %%
path.getsize(fname)
# Out:
# 1387547

# %%
# !head "$fname"
# Out:
# StartDate,EndDate,Status,IPAddress,Progress,Duration (in seconds),Finished,RecordedDate,ResponseId,RecipientLastName,RecipientFirstName,RecipientEmail,ExternalReference,LocationLatitude,LocationLongitude,DistributionChannel,UserLanguage,Q63_First Click,Q63_Last Click,Q63_Page Submit,Q63_Click Count,facilitator_explain,facilitator_confidence,facilitator_newideas,facilitator_diffperspect,facilitator_confmanage,facilitator_diverseopin,facilitator_suggest,facilitator1_strengt,facilitator1_improve,Q72_First Click,Q72_Last Click,Q72_Page Submit,Q72_Click Count,personalgain_gaininfo,personalgain_gainskill,personalgain_useinfo,personalgain_taughtothers,personalgain_changebeh,boardgain_data,boardgain_opportunity,boardgain_riskprotect,boardgain_selectstrategy,boardgain_structured,boardgain_representatives,isks_knowledge,isks_skills,Q65_First Click,Q65_Last Click,Q65_Page Submit,Q65_Click Count,boardrepresent_agencies,boardrepresent_raceeth,boardrepresent_gender,boardrepresent_sexorient,boardre
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv(fname)

# %%
len(df)
# Out:
# 502

# %%
df.columns
# Out:
# Index(['StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress',
#        'Duration (in seconds)', 'Finished', 'RecordedDate', 'ResponseId',
#        'RecipientLastName',
#        ...
#        'whichboard', 'whichboard_3_TEXT', 'sector', 'sector_16_TEXT',
#        'workexp', 'age', 'gender', 'orientation', 'raceeth', 'CSPV_ID'],
#       dtype='object', length=191)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Columns: 191 entries, StartDate to CSPV_ID
# dtypes: object(191)
# memory usage: 749.2+ KB

# %%
df.head()
# Out:
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"America/De...
# 2                                2018-09-06 09:21:30
# 3                                2018-09-06 09:21:30
# 4                                2018-09-06 09:21:30
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 2                                2018-09-06 09:21:30            Survey Test
# 3                                2018-09-06 09:21:30            Survey Test
# 4                                2018-09-06 09:21:31            Survey Test
#
#                   IPAddress                 Progress    Duration (in seconds)  \
# 0                IP Address                 Progress    Duration (in seconds)
# ...

# %%
df.dtypes
# Out:
# StartDate                   object
# EndDate                     object
# Status                      object
# IPAddress                   object
# Progress                    object
# Duration (in seconds)       object
# Finished                    object
# RecordedDate                object
# ResponseId                  object
# RecipientLastName           object
# RecipientFirstName          object
# RecipientEmail              object
# ExternalReference           object
# LocationLatitude            object
# LocationLongitude           object
# DistributionChannel         object
# UserLanguage                object
# Q63_First Click             object
# Q63_Last Click              object
# Q63_Page Submit             object
# Q63_Click Count             object
# facilitator_explain         object
# facilitator_confidence      object
# facilitator_newideas        object
# facilitator_diffperspect    object
# facilitator_confmanage      object
# facilitator_diverseopin     object
# ...

# %%
import numpy as np

# %%
dataSet = df.loc[2:502]
dataSet
# Out:
#                StartDate              EndDate       Status IPAddress Progress  \
# 2    2018-09-06 09:21:30  2018-09-06 09:21:30  Survey Test       NaN      100
# 3    2018-09-06 09:21:30  2018-09-06 09:21:30  Survey Test       NaN      100
# 4    2018-09-06 09:21:30  2018-09-06 09:21:31  Survey Test       NaN      100
# 5    2018-09-06 09:21:31  2018-09-06 09:21:31  Survey Test       NaN      100
# 6    2018-09-06 09:21:31  2018-09-06 09:21:31  Survey Test       NaN      100
# 7    2018-09-06 09:21:31  2018-09-06 09:21:31  Survey Test       NaN      100
# 8    2018-09-06 09:21:32  2018-09-06 09:21:32  Survey Test       NaN      100
# 9    2018-09-06 09:21:32  2018-09-06 09:21:32  Survey Test       NaN      100
# 10   2018-09-06 09:21:32  2018-09-06 09:21:32  Survey Test       NaN      100
# 11   2018-09-06 09:21:33  2018-09-06 09:21:33  Survey Test       NaN      100
# 12   2018-09-06 09:21:33  2018-09-06 09:21:33  Survey Test       NaN      100
# ...

# %%
df[['age','gender','orientation','raceeth','EndDate','LocationLatitude','LocationLongitude']][2:502]
# Out:
#                  age                                           gender  \
# 2    36-45 years old                                             Male
# 3        18 or under  Do not identify as male, female, or transgender
# 4        18 or under  Do not identify as male, female, or transgender
# 5    26-35 years old                                           Female
# 6        18 or under                                      Transgender
# 7    46-55 years old                                           Female
# 8    36-45 years old                                             Male
# 9    46-55 years old                                             Male
# 10   36-45 years old                                           Female
# 11       18 or under                                             Male
# 12       18 or under  Do not identify as male, female, or transgender
# 13   26-35 years old                                           Female
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=502, step=1)

# %%
df.index = df['EndDate']
df.index
# Out:
# Index(['End Date', '{"ImportId":"endDate","timeZone":"America/Denver"}',
#        '2018-09-06 09:21:30', '2018-09-06 09:21:30', '2018-09-06 09:21:31',
#        '2018-09-06 09:21:31', '2018-09-06 09:21:31', '2018-09-06 09:21:31',
#        '2018-09-06 09:21:32', '2018-09-06 09:21:32',
#        ...
#        '2018-09-06 09:24:07', '2018-09-06 09:24:07', '2018-09-06 09:24:07',
#        '2018-09-06 09:24:08', '2018-09-06 09:24:08', '2018-09-06 09:24:08',
#        '2018-09-06 09:24:08', '2018-09-06 09:24:09', '2018-09-06 09:24:09',
#        '2018-09-06 09:24:09'],
#       dtype='object', name='EndDate', length=502)

# %%
import numpy as np

# %%
import pytz

# %%
# %pwd
# Out:
# '/Users/kerstimcgee/lc101/DataVis-Concept-CU'

# %%
import geo

# %%
import sys
sys.path
# Out:
# ['',
#  '/Users/kerstimcgee/lc101/DataVis-Concept-CU',
#  '/Users/kerstimcgee/anaconda3/lib/python37.zip',
#  '/Users/kerstimcgee/anaconda3/lib/python3.7',
#  '/Users/kerstimcgee/anaconda3/lib/python3.7/lib-dynload',
#  '/Users/kerstimcgee/.local/lib/python3.7/site-packages',
#  '/Users/kerstimcgee/anaconda3/lib/python3.7/site-packages',
#  '/Users/kerstimcgee/anaconda3/lib/python3.7/site-packages/aeosa',
#  '/Users/kerstimcgee/anaconda3/lib/python3.7/site-packages/pip-18.1-py3.7.egg',
#  '/Users/kerstimcgee/anaconda3/lib/python3.7/site-packages/IPython/extensions',
#  '/Users/kerstimcgee/.ipython']

# %%
??geo

# %%
latStr = df['LocationLatitude'] = df['LocationLatitude'].astype('|S')
latStr.dtype
print(latStr)

longStr = df['LocationLongitude'] = df['LocationLongitude'].astype('|S')
longStr.dtype
print(longStr)
# Out:
# EndDate
# End Date                                                            b'Location Latitude'
# {"ImportId":"endDate","timeZone":"America/Denver"}    b'{"ImportId":"locationLatitude"}'
# 2018-09-06 09:21:30                                                   b'40.014999389648'
# 2018-09-06 09:21:30                                                   b'40.014999389648'
# 2018-09-06 09:21:31                                                   b'40.014999389648'
# 2018-09-06 09:21:31                                                   b'40.014999389648'
# 2018-09-06 09:21:31                                                   b'40.014999389648'
# 2018-09-06 09:21:31                                                   b'40.014999389648'
# 2018-09-06 09:21:32                                                   b'40.014999389648'
# 2018-09-06 09:21:32                                                   b'40.014999389648'
# ...

# %% [markdown]
# ***Here, we need to convert all from str to int :)

# %%
pd.to_numeric(latStr, errors='coerce')
# Out:
# EndDate
# End Date                                                    NaN
# {"ImportId":"endDate","timeZone":"America/Denver"}          NaN
# 2018-09-06 09:21:30                                   40.014999
# 2018-09-06 09:21:30                                   40.014999
# 2018-09-06 09:21:31                                   40.014999
# 2018-09-06 09:21:31                                   40.014999
# 2018-09-06 09:21:31                                   40.014999
# 2018-09-06 09:21:31                                   40.014999
# 2018-09-06 09:21:32                                   40.014999
# 2018-09-06 09:21:32                                   40.014999
# 2018-09-06 09:21:32                                   40.014999
# 2018-09-06 09:21:33                                   40.014999
# 2018-09-06 09:21:33                                   40.014999
# 2018-09-06 09:21:33                                   40.014999
# 2018-09-06 09:21:33                                   40.014999
# ...

# %%
latStr.dtype
# Out:
# dtype('S31')

# %% [markdown]
# ***The above is not completed with circle module...the string/strings are still not converted to int (also, unsure if entire is a string or if individual strings?)

# %%
import geo

# %%
# latlon = [ (40.014999389648, -105.27059936523)]
# mapit = folium.Map(location=[40.014999389648, -105.27059936523], zoom_start=20)
# mapit

# %%
forGradience = df[['ResponseId','orientation','raceeth']][2:502]
forGradience
# Out:
#                             ResponseId              orientation  \
# EndDate
# 2018-09-06 09:21:30  R_1NfmUai8ZNjXxIh                    Other
# 2018-09-06 09:21:30  R_2sBx7FtrZ5nsCXz  Heterosexual (Straight)
# 2018-09-06 09:21:31  R_9HO0gHtphuzSXpX                    Other
# 2018-09-06 09:21:31  R_cNlijOVTJgy3keV           Gay or Lesbian
# 2018-09-06 09:21:31  R_37AQ7sHgnOU5977                    Other
# 2018-09-06 09:21:31  R_8BTleNXXe7Mw1Y9                    Other
# 2018-09-06 09:21:32  R_bd4iCwHXxOIKWwZ                 Bisexual
# 2018-09-06 09:21:32  R_1O1v9coYIF3FCm1  Heterosexual (Straight)
# 2018-09-06 09:21:32  R_2bFdkKHesMP8I4t  Heterosexual (Straight)
# 2018-09-06 09:21:33  R_8CFCQ3LUh1muyLX                 Bisexual
# 2018-09-06 09:21:33  R_9RYYz3jJreVfDz7                 Bisexual
# 2018-09-06 09:21:33  R_dgSwqpiZcHn5mgl                 Bisexual
# 2018-09-06 09:21:33  R_38AN9HpVBtvcaEJ                    Other
# ...

# %%
forGradience.dtypes
# Out:
# ResponseId     object
# orientation    object
# raceeth        object
# dtype: object

# %%
orientation = df['orientation'].astype('|S')
orientation.dtype
print(orientation)

raceeth = df['raceeth'].astype('|S')
raceeth.dtype
print(raceeth)
# Out:
# EndDate
# End Date                                              b'Which\r\nof the following best describes you?'
# {"ImportId":"endDate","timeZone":"America/Denver"}                             b'{"ImportId":"QID38"}'
# 2018-09-06 09:21:30                                                                           b'Other'
# 2018-09-06 09:21:30                                                         b'Heterosexual (Straight)'
# 2018-09-06 09:21:31                                                                           b'Other'
# 2018-09-06 09:21:31                                                                  b'Gay or Lesbian'
# 2018-09-06 09:21:31                                                                           b'Other'
# 2018-09-06 09:21:31                                                                           b'Other'
# 2018-09-06 09:21:32                                                                        b'Bisexual'
# ...

# %%
raceeth.dtype
# Out:
# dtype('S41')

# %%
orientationCounts = forGradience['orientation'].value_counts()
raceCounts = forGradience['raceeth'].value_counts()
print(orientationCounts)
print("---")
print(raceCounts[0])
# Out:
# Gay or Lesbian             130
# Heterosexual (Straight)    126
# Other                      124
# Bisexual                   120
# Name: orientation, dtype: int64
# ---
# 79

# %%
xAxis = forGradience['orientation'].value_counts() 
yAxis = forGradience['raceeth'].value_counts()
xAxis,"*****************************************************", yAxis
# Out:
# (Gay or Lesbian             130
#  Heterosexual (Straight)    126
#  Other                      124
#  Bisexual                   120
#  Name: orientation, dtype: int64,
#  '*****************************************************',
#  American Indian or Alaska Native             79
#  Hispanic or Latino                           74
#  Two or More Races                            73
#  White or Caucasian                           72
#  Asian                                        72
#  Native Hawaiian or Other Pacific Islander    66
#  Black or African American                    64
#  Name: raceeth, dtype: int64)

# %%
import seaborn as sns

# %%
import sqlite3

# %%
#orientationList = ['Gay or Lesbian', 'Heterosexual (Straight)']
#raceList = ['American Indian or Alaska Native', 'Hispanic or Latino', 'Two or More Races']

#twoD_DF = DataFrame

#for orientation in orientationList:
   # print(orientation)
  #  s = []
  #  for race in raceList:
    #    s.append(forGradience[(forGradience.orientation == orientation) & (forGradience.raceeth == race)])
   # S = Series(data=s, index=raceList)
  #  print(S)
  #  twoD_DF[orientation] = S    
 #   print("=====")

gayAmIndian1 = forGradience[(forGradience.orientation == 'Gay or Lesbian') & (forGradience.raceeth == 'American Indian or Alaska Native')]
gayLatina1 = forGradience[(forGradience.orientation == 'Gay or Lesbian') & (forGradience.raceeth == 'Hispanic or Latino')]
gayBiRacial1 = forGradience[(forGradience.orientation == 'Gay or Lesbian') & (forGradience.raceeth == 'Two or More Races')]
gayWhite1 = forGradience[(forGradience.orientation == 'Gay or Lesbian') & (forGradience.raceeth == 'White or Caucasian')]
gayHaw1 = forGradience[(forGradience.orientation == 'Gay or Lesbian') & (forGradience.raceeth == 'Native Hawaiian or Other Pacific Islander')]
gayBlack1 = forGradience[(forGradience.orientation == 'Gay or Lesbian') & (forGradience.raceeth == 'Black or African American')]
gayAsian1 = forGradience[(forGradience.orientation == 'Gay or Lesbian') & (forGradience.raceeth == 'Asian')]

straightAmIndian1 = forGradience[(forGradience.orientation == 'Heterosexual (Straight)') & (forGradience.raceeth == 'American Indian or Alaska Native')]
straightLatina1 = forGradience[(forGradience.orientation == 'Heterosexual (Straight)') & (forGradience.raceeth == 'Hispanic or Latino')]
straightBiRacial1 = forGradience[(forGradience.orientation == 'Heterosexual (Straight)') & (forGradience.raceeth == 'Two or More Races')]
straightWhite1 = forGradience[(forGradience.orientation == 'Heterosexual (Straight)') & (forGradience.raceeth == 'White or Caucasian')]
straightHaw1 = forGradience[(forGradience.orientation == 'Heterosexual (Straight)') & (forGradience.raceeth == 'Native Hawaiian or Other Pacific Islander')]
straightBlack1 = forGradience[(forGradience.orientation == 'Heterosexual (Straight)') & (forGradience.raceeth == 'Black or African American')]
straightAsian1 = forGradience[(forGradience.orientation == 'Heterosexual (Straight)') & (forGradience.raceeth == 'Asian')]

otherAmIndian1 = forGradience[(forGradience.orientation == 'Other') & (forGradience.raceeth == 'American Indian or Alaska Native')]
otherLatina1 = forGradience[(forGradience.orientation == 'Other') & (forGradience.raceeth == 'Hispanic or Latino')]
otherBiRacial1 = forGradience[(forGradience.orientation == 'Other') & (forGradience.raceeth == 'Two or More Races')]
otherWhite1 = forGradience[(forGradience.orientation == 'Other') & (forGradience.raceeth == 'White or Caucasian')]
otherHaw1 = forGradience[(forGradience.orientation == 'Other') & (forGradience.raceeth == 'Native Hawaiian or Other Pacific Islander')]
otherBlack1 = forGradience[(forGradience.orientation == 'Other') & (forGradience.raceeth == 'Black or African American')]
otherAsian1 = forGradience[(forGradience.orientation == 'Other') & (forGradience.raceeth == 'Asian')]

biAmIndian1 = forGradience[(forGradience.orientation == 'Bisexual') & (forGradience.raceeth == 'American Indian or Alaska Native')]
biLatina1 = forGradience[(forGradience.orientation == 'Bisexual') & (forGradience.raceeth == 'Hispanic or Latino')]
biBiRacial1 = forGradience[(forGradience.orientation == 'Bisexual') & (forGradience.raceeth == 'Two or More Races')]
biWhite1 = forGradience[(forGradience.orientation == 'Bisexual') & (forGradience.raceeth == 'White or Caucasian')]
biHaw1 = forGradience[(forGradience.orientation == 'Bisexual') & (forGradience.raceeth == 'Native Hawaiian or Other Pacific Islander')]
biBlack1 = forGradience[(forGradience.orientation == 'Bisexual') & (forGradience.raceeth == 'Black or African American')]
biAsian1 = forGradience[(forGradience.orientation == 'Bisexual') & (forGradience.raceeth == 'Asian')]

# %%
gayAmIndian = (gayAmIndian1.orientation).value_counts()/79
gayLatina = (gayLatina1.orientation).value_counts()/74
gayBiRacial = (gayBiRacial1.orientation).value_counts()/73
gayWhite = (gayWhite1.orientation).value_counts()/72
gayHaw = (gayHaw1.orientation).value_counts()/66
gayBlack = (gayBlack1.orientation).value_counts()/64
gayAsian = (gayAsian1.orientation).value_counts()/72

straightAmIndian = (straightAmIndian1.orientation).value_counts()/79
straightLatina = (straightLatina1.orientation).value_counts()/74
straightBiRacial = (straightBiRacial1.orientation).value_counts()/73
straightWhite = (straightWhite1.orientation).value_counts()/72
straightHaw = (straightHaw1.orientation).value_counts()/66
straightBlack = (straightBlack1.orientation).value_counts()/64
straightAsian = (straightAsian1.orientation).value_counts()/72

otherAmIndian = (otherAmIndian1.orientation).value_counts()/79
otherLatina = (otherLatina1.orientation).value_counts()/74
otherBiRacial = (otherBiRacial1.orientation).value_counts()/73
otherWhite = (otherWhite1.orientation).value_counts()/72
otherHaw = (otherHaw1.orientation).value_counts()/66
otherBlack = (otherBlack1.orientation).value_counts()/64
otherAsian = (otherAsian1.orientation).value_counts()/72

biAmIndian = (biAmIndian1.orientation).value_counts()/79
biLatina = (biLatina1.orientation).value_counts()/74
biBiRacial = (biBiRacial1.orientation).value_counts()/73
biWhite = (biWhite1.orientation).value_counts()/72
biHaw = (biHaw1.orientation).value_counts()/66
biBlack = (biBlack1.orientation).value_counts()/64
biAsian = (biAsian1.orientation).value_counts()/72

# %%
import seaborn as sns

# %%
Index=['AmInd', 'Latina', 'Biracial', 'White', 'Hawaiian', 'Black', 'Asian']

gaySeries = pd.Series(
    data=[gayAmIndian[0], gayLatina[0], gayBiRacial[0], gayWhite[0], gayHaw[0], gayBlack[0], gayAsian[0]],
    index=['AmInd', 'Latina', 'Biracial', 'White', 'Hawaiian', 'Black', 'Asian']
)
straightSeries = pd.Series(
    data=[straightAmIndian[0], straightLatina[0], straightBiRacial[0], straightWhite[0], straightHaw[0], straightBlack[0], straightAsian[0]],
    index=['AmInd', 'Latina', 'Biracial', 'White', 'Hawaiian', 'Black', 'Asian']
)
otherSeries = pd.Series(
    data=[otherAmIndian[0], otherLatina[0], otherBiRacial[0], otherWhite[0], otherHaw[0], otherBlack[0], otherAsian[0]],
    index=['AmInd', 'Latina', 'Biracial', 'White', 'Hawaiian', 'Black', 'Asian']
)
biSeries = pd.Series(
    data=[biAmIndian[0], biLatina[0], biBiRacial[0], biWhite[0], biHaw[0], biBlack[0], biAsian[0]],
    index=['AmInd', 'Latina', 'Biracial', 'White', 'Hawaiian', 'Black', 'Asian']
)


hm = pd.DataFrame([gaySeries, straightSeries, otherSeries, biSeries], columns=Index, index=["gay", "straight", "other", "bi"])
print(hm)
# Out:
#              AmInd    Latina  Biracial     White  Hawaiian     Black     Asian
# gay       0.278481  0.243243  0.232877  0.208333  0.242424  0.312500  0.305556
# straight  0.253165  0.297297  0.287671  0.236111  0.257576  0.171875  0.250000
# other     0.240506  0.256757  0.260274  0.333333  0.272727  0.203125  0.166667
# bi        0.227848  0.202703  0.219178  0.222222  0.227273  0.312500  0.277778

# %%
sns.heatmap(hm, annot=True)

# %% [markdown]
# New Data Pull
#
# You can tell which items hang together as a scale by looking at their prefix (e.g., boardrepresent). Scale scores are just an average score. It's also important that a single site's score gets compared to the average score for all respondents (across all sites).
#
# I think in general simple is better - a simple barchart will work for a broader range of data
