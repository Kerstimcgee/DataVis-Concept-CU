# %%
from os import path
fname = './CoalitionSurveyTesting2018.csv'

# %%
path.getsize(fname)
# Out:
# 1387547

# %%
# !head "$fname"
# Out:
# StartDate,EndDate,Status,IPAddress,Progress,Duration (in seconds),Finished,RecordedDate,ResponseId,RecipientLastName,RecipientFirstName,RecipientEmail,ExternalReference,LocationLatitude,LocationLongitude,DistributionChannel,UserLanguage,Q63_First Click,Q63_Last Click,Q63_Page Submit,Q63_Click Count,facilitator_explain,facilitator_confidence,facilitator_newideas,facilitator_diffperspect,facilitator_confmanage,facilitator_diverseopin,facilitator_suggest,facilitator1_strengt,facilitator1_improve,Q72_First Click,Q72_Last Click,Q72_Page Submit,Q72_Click Count,personalgain_gaininfo,personalgain_gainskill,personalgain_useinfo,personalgain_taughtothers,personalgain_changebeh,boardgain_data,boardgain_opportunity,boardgain_riskprotect,boardgain_selectstrategy,boardgain_structured,boardgain_representatives,isks_knowledge,isks_skills,Q65_First Click,Q65_Last Click,Q65_Page Submit,Q65_Click Count,boardrepresent_agencies,boardrepresent_raceeth,boardrepresent_gender,boardrepresent_sexorient,boardre
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv(fname)

# %%
len(df)
# Out:
# 502

# %%
df.columns
# Out:
# Index(['StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress',
#        'Duration (in seconds)', 'Finished', 'RecordedDate', 'ResponseId',
#        'RecipientLastName',
#        ...
#        'whichboard', 'whichboard_3_TEXT', 'sector', 'sector_16_TEXT',
#        'workexp', 'age', 'gender', 'orientation', 'raceeth', 'CSPV_ID'],
#       dtype='object', length=191)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 502 entries, 0 to 501
# Columns: 191 entries, StartDate to CSPV_ID
# dtypes: object(191)
# memory usage: 749.2+ KB

# %%
df.head()
# Out:
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"America/De...
# 2                                2018-09-06 09:21:30
# 3                                2018-09-06 09:21:30
# 4                                2018-09-06 09:21:30
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 2                                2018-09-06 09:21:30            Survey Test
# 3                                2018-09-06 09:21:30            Survey Test
# 4                                2018-09-06 09:21:31            Survey Test
#
#                   IPAddress                 Progress    Duration (in seconds)  \
# 0                IP Address                 Progress    Duration (in seconds)
# ...

# %%
df.dtypes
# Out:
# StartDate                   object
# EndDate                     object
# Status                      object
# IPAddress                   object
# Progress                    object
# Duration (in seconds)       object
# Finished                    object
# RecordedDate                object
# ResponseId                  object
# RecipientLastName           object
# RecipientFirstName          object
# RecipientEmail              object
# ExternalReference           object
# LocationLatitude            object
# LocationLongitude           object
# DistributionChannel         object
# UserLanguage                object
# Q63_First Click             object
# Q63_Last Click              object
# Q63_Page Submit             object
# Q63_Click Count             object
# facilitator_explain         object
# facilitator_confidence      object
# facilitator_newideas        object
# facilitator_diffperspect    object
# facilitator_confmanage      object
# facilitator_diverseopin     object
# ...

# %%
import numpy as np

# %%
dataSet = df.loc[2:502]
dataSet
# Out:
#                StartDate              EndDate       Status IPAddress Progress  \
# 2    2018-09-06 09:21:30  2018-09-06 09:21:30  Survey Test       NaN      100
# 3    2018-09-06 09:21:30  2018-09-06 09:21:30  Survey Test       NaN      100
# 4    2018-09-06 09:21:30  2018-09-06 09:21:31  Survey Test       NaN      100
# 5    2018-09-06 09:21:31  2018-09-06 09:21:31  Survey Test       NaN      100
# 6    2018-09-06 09:21:31  2018-09-06 09:21:31  Survey Test       NaN      100
# 7    2018-09-06 09:21:31  2018-09-06 09:21:31  Survey Test       NaN      100
# 8    2018-09-06 09:21:32  2018-09-06 09:21:32  Survey Test       NaN      100
# 9    2018-09-06 09:21:32  2018-09-06 09:21:32  Survey Test       NaN      100
# 10   2018-09-06 09:21:32  2018-09-06 09:21:32  Survey Test       NaN      100
# 11   2018-09-06 09:21:33  2018-09-06 09:21:33  Survey Test       NaN      100
# 12   2018-09-06 09:21:33  2018-09-06 09:21:33  Survey Test       NaN      100
# ...

# %%
df[['age','gender','orientation','raceeth','EndDate','LocationLatitude','LocationLongitude']][2:502]
# Out:
#                  age                                           gender  \
# 2    36-45 years old                                             Male
# 3        18 or under  Do not identify as male, female, or transgender
# 4        18 or under  Do not identify as male, female, or transgender
# 5    26-35 years old                                           Female
# 6        18 or under                                      Transgender
# 7    46-55 years old                                           Female
# 8    36-45 years old                                             Male
# 9    46-55 years old                                             Male
# 10   36-45 years old                                           Female
# 11       18 or under                                             Male
# 12       18 or under  Do not identify as male, female, or transgender
# 13   26-35 years old                                           Female
# ...

# %%
df.index
# Out:
# Index(['End Date', '{"ImportId":"endDate","timeZone":"America/Denver"}',
#        '2018-09-06 09:21:30', '2018-09-06 09:21:30', '2018-09-06 09:21:31',
#        '2018-09-06 09:21:31', '2018-09-06 09:21:31', '2018-09-06 09:21:31',
#        '2018-09-06 09:21:32', '2018-09-06 09:21:32',
#        ...
#        '2018-09-06 09:24:07', '2018-09-06 09:24:07', '2018-09-06 09:24:07',
#        '2018-09-06 09:24:08', '2018-09-06 09:24:08', '2018-09-06 09:24:08',
#        '2018-09-06 09:24:08', '2018-09-06 09:24:09', '2018-09-06 09:24:09',
#        '2018-09-06 09:24:09'],
#       dtype='object', name='EndDate', length=502)

# %%
df.index = df['EndDate']
df.index
# Out:
# Index(['End Date', '{"ImportId":"endDate","timeZone":"America/Denver"}',
#        '2018-09-06 09:21:30', '2018-09-06 09:21:30', '2018-09-06 09:21:31',
#        '2018-09-06 09:21:31', '2018-09-06 09:21:31', '2018-09-06 09:21:31',
#        '2018-09-06 09:21:32', '2018-09-06 09:21:32',
#        ...
#        '2018-09-06 09:24:07', '2018-09-06 09:24:07', '2018-09-06 09:24:07',
#        '2018-09-06 09:24:08', '2018-09-06 09:24:08', '2018-09-06 09:24:08',
#        '2018-09-06 09:24:08', '2018-09-06 09:24:09', '2018-09-06 09:24:09',
#        '2018-09-06 09:24:09'],
#       dtype='object', name='EndDate', length=502)

# %%
import numpy as np

# %%
import pytz

# %%
# %pwd
# Out:
# '/Users/kerstimcgee/lc101/DataVis-Concept-CU'

# %%
import geo

# %%
import sys
sys.path
# Out:
# ['',
#  '/Users/kerstimcgee/lc101/DataVis-Concept-CU',
#  '/Users/kerstimcgee/anaconda3/lib/python37.zip',
#  '/Users/kerstimcgee/anaconda3/lib/python3.7',
#  '/Users/kerstimcgee/anaconda3/lib/python3.7/lib-dynload',
#  '/Users/kerstimcgee/.local/lib/python3.7/site-packages',
#  '/Users/kerstimcgee/anaconda3/lib/python3.7/site-packages',
#  '/Users/kerstimcgee/anaconda3/lib/python3.7/site-packages/aeosa',
#  '/Users/kerstimcgee/anaconda3/lib/python3.7/site-packages/pip-18.1-py3.7.egg',
#  '/Users/kerstimcgee/anaconda3/lib/python3.7/site-packages/IPython/extensions',
#  '/Users/kerstimcgee/.ipython']

# %%
??geo

# %%
latStr = df['LocationLatitude'] = df['LocationLatitude'].astype('|S')
latStr.dtype
print(latStr)

longStr = df['LocationLongitude'] = df['LocationLongitude'].astype('|S')
longStr.dtype
print(longStr)
# Out:
# EndDate
# End Date                                                            b'Location Latitude'
# {"ImportId":"endDate","timeZone":"America/Denver"}    b'{"ImportId":"locationLatitude"}'
# 2018-09-06 09:21:30                                                   b'40.014999389648'
# 2018-09-06 09:21:30                                                   b'40.014999389648'
# 2018-09-06 09:21:31                                                   b'40.014999389648'
# 2018-09-06 09:21:31                                                   b'40.014999389648'
# 2018-09-06 09:21:31                                                   b'40.014999389648'
# 2018-09-06 09:21:31                                                   b'40.014999389648'
# 2018-09-06 09:21:32                                                   b'40.014999389648'
# 2018-09-06 09:21:32                                                   b'40.014999389648'
# ...

# %% [markdown]
# ***Here, we need to convert all from str to int :)

# %%
pd.to_numeric(latStr, errors='coerce')
# Out:
# EndDate
# End Date                                                    NaN
# {"ImportId":"endDate","timeZone":"America/Denver"}          NaN
# 2018-09-06 09:21:30                                   40.014999
# 2018-09-06 09:21:30                                   40.014999
# 2018-09-06 09:21:31                                   40.014999
# 2018-09-06 09:21:31                                   40.014999
# 2018-09-06 09:21:31                                   40.014999
# 2018-09-06 09:21:31                                   40.014999
# 2018-09-06 09:21:32                                   40.014999
# 2018-09-06 09:21:32                                   40.014999
# 2018-09-06 09:21:32                                   40.014999
# 2018-09-06 09:21:33                                   40.014999
# 2018-09-06 09:21:33                                   40.014999
# 2018-09-06 09:21:33                                   40.014999
# 2018-09-06 09:21:33                                   40.014999
# ...

# %%
latStr.dtype
# Out:
# dtype('S31')

# %% [markdown]
# ***The above is not completed with circle module...the string/strings are still not converted to int (also, unsure if entire is a string or if individual strings?)

# %%
import geo

# %%
import folium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-87-173c1173bf1c> in <module>
# ----> 1 import folium
#
# ModuleNotFoundError: No module named 'folium'

# %%
latlon = [ (40.014999389648, -105.27059936523)]
mapit = folium.Map(location=[40.014999389648, -105.27059936523], zoom_start=20)
mapit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-0dbe4fb07109> in <module>
#       1 latlon = [ (40.014999389648, -105.27059936523)]
# ----> 2 mapit = folium.Map(location=[40.014999389648, -105.27059936523], zoom_start=20)
#       3 mapit
#
# NameError: name 'folium' is not defined

# %%
forGradience = df[['ResponseId','orientation','raceeth']][2:502]
forGradience
# Out:
#                             ResponseId              orientation  \
# EndDate
# 2018-09-06 09:21:30  R_1NfmUai8ZNjXxIh                    Other
# 2018-09-06 09:21:30  R_2sBx7FtrZ5nsCXz  Heterosexual (Straight)
# 2018-09-06 09:21:31  R_9HO0gHtphuzSXpX                    Other
# 2018-09-06 09:21:31  R_cNlijOVTJgy3keV           Gay or Lesbian
# 2018-09-06 09:21:31  R_37AQ7sHgnOU5977                    Other
# 2018-09-06 09:21:31  R_8BTleNXXe7Mw1Y9                    Other
# 2018-09-06 09:21:32  R_bd4iCwHXxOIKWwZ                 Bisexual
# 2018-09-06 09:21:32  R_1O1v9coYIF3FCm1  Heterosexual (Straight)
# 2018-09-06 09:21:32  R_2bFdkKHesMP8I4t  Heterosexual (Straight)
# 2018-09-06 09:21:33  R_8CFCQ3LUh1muyLX                 Bisexual
# 2018-09-06 09:21:33  R_9RYYz3jJreVfDz7                 Bisexual
# 2018-09-06 09:21:33  R_dgSwqpiZcHn5mgl                 Bisexual
# 2018-09-06 09:21:33  R_38AN9HpVBtvcaEJ                    Other
# ...

# %%
forGradience.dtypes
# Out:
# ResponseId     object
# orientation    object
# raceeth        object
# dtype: object

# %%
orientation = df['orientation'].astype('|S')
orientation.dtype
print(orientation)

raceeth = df['raceeth'].astype('|S')
raceeth.dtype
print(raceeth)
# Out:
# EndDate
# End Date                                              b'Which\r\nof the following best describes you?'
# {"ImportId":"endDate","timeZone":"America/Denver"}                             b'{"ImportId":"QID38"}'
# 2018-09-06 09:21:30                                                                           b'Other'
# 2018-09-06 09:21:30                                                         b'Heterosexual (Straight)'
# 2018-09-06 09:21:31                                                                           b'Other'
# 2018-09-06 09:21:31                                                                  b'Gay or Lesbian'
# 2018-09-06 09:21:31                                                                           b'Other'
# 2018-09-06 09:21:31                                                                           b'Other'
# 2018-09-06 09:21:32                                                                        b'Bisexual'
# ...

# %%
raceeth.dtype
# Out:
# dtype('S41')

# %%
xAxis = forGradience['orientation'].value_counts() 
yAxis = forGradience['raceeth'].value_counts()
xAxis,"*****************************************************", yAxis
# Out:
# (Gay or Lesbian             130
#  Heterosexual (Straight)    126
#  Other                      124
#  Bisexual                   120
#  Name: orientation, dtype: int64,
#  '*****************************************************',
#  American Indian or Alaska Native             79
#  Hispanic or Latino                           74
#  Two or More Races                            73
#  White or Caucasian                           72
#  Asian                                        72
#  Native Hawaiian or Other Pacific Islander    66
#  Black or African American                    64
#  Name: raceeth, dtype: int64)

# %%
import seaborn as sns

# %%
import sqlite3

# %%
gayAmIndian = forGradience[(forGradience.orientation == 'Gay or Lesbian') & (forGradience.raceeth == 'American Indian or Alaska Native')]
gayLatina = forGradience[(forGradience.orientation == 'Gay or Lesbian') & (forGradience.raceeth == 'Hispanic or Latino')]
gayBiRacial = forGradience[(forGradience.orientation == 'Gay or Lesbian') & (forGradience.raceeth == 'Two or More Races')]
gayWhite = forGradience[(forGradience.orientation == 'Gay or Lesbian') & (forGradience.raceeth == 'White or Caucasian')]
gayHaw = forGradience[(forGradience.orientation == 'Gay or Lesbian') & (forGradience.raceeth == 'Native Hawaiian or Other Pacific Islander')]
gayBlack = forGradience[(forGradience.orientation == 'Gay or Lesbian') & (forGradience.raceeth == 'Black or African American')]
gayAsian = forGradience[(forGradience.orientation == 'Gay or Lesbian') & (forGradience.raceeth == 'Asian')]

straightAmIndian = forGradience[(forGradience.orientation == 'Heterosexual /(Straight)') & (forGradience.raceeth == 'American Indian or Alaska Native')]
straightLatina = forGradience[(forGradience.orientation == 'Heterosexual /(Straight)') & (forGradience.raceeth == 'Hispanic or Latino')]
straightBiRacial = forGradience[(forGradience.orientation == 'Heterosexual /(Straight)') & (forGradience.raceeth == 'Two or More Races')]
straightWhite = forGradience[(forGradience.orientation == 'Heterosexual /(Straight)') & (forGradience.raceeth == 'White or Caucasian')]
straightHaw = forGradience[(forGradience.orientation == 'Heterosexual /(Straight)') & (forGradience.raceeth == 'Native Hawaiian or Other Pacific Islander')]
straightBlack = forGradience[(forGradience.orientation == 'Heterosexual /(Straight)') & (forGradience.raceeth == 'Black or African American')]
straightAsian = forGradience[(forGradience.orientation == 'Heterosexual /(Straight)') & (forGradience.raceeth == 'Asian')]

otherAmIndian = forGradience[(forGradience.orientation == 'Other') & (forGradience.raceeth == 'American Indian or Alaska Native')]
otherLatina = forGradience[(forGradience.orientation == 'Other') & (forGradience.raceeth == 'Hispanic or Latino')]
otherBiRacial = forGradience[(forGradience.orientation == 'Other') & (forGradience.raceeth == 'Two or More Races')]
otherWhite = forGradience[(forGradience.orientation == 'Other') & (forGradience.raceeth == 'White or Caucasian')]
otherHaw = forGradience[(forGradience.orientation == 'Other') & (forGradience.raceeth == 'Native Hawaiian or Other Pacific Islander')]
otherBlack = forGradience[(forGradience.orientation == 'Other') & (forGradience.raceeth == 'Black or African American')]
otherAsian = forGradience[(forGradience.orientation == 'Other') & (forGradience.raceeth == 'Asian')]

biAmIndian = forGradience[(forGradience.orientation == 'Bisexual') & (forGradience.raceeth == 'American Indian or Alaska Native')]
biLatina = forGradience[(forGradience.orientation == 'Bisexual') & (forGradience.raceeth == 'Hispanic or Latino')]
biBiRacial = forGradience[(forGradience.orientation == 'Bisexual') & (forGradience.raceeth == 'Two or More Races')]
biWhite = forGradience[(forGradience.orientation == 'Bisexual') & (forGradience.raceeth == 'White or Caucasian')]
biHaw = forGradience[(forGradience.orientation == 'Bisexual') & (forGradience.raceeth == 'Native Hawaiian or Other Pacific Islander')]
biBlack = forGradience[(forGradience.orientation == 'Bisexual') & (forGradience.raceeth == 'Black or African American')]
biAsian = forGradience[(forGradience.orientation == 'Bisexual') & (forGradience.raceeth == 'Asian')]

# %%
gayAmIndian = (gayAmIndian.orientation).value_counts()/79
gayLatina = (gayLatina.orientation).value_counts()/74
gayBiRacial = (gayBiRacial.orientation).value_counts()/73
gayWhite = (gayWhite.orientation).value_counts()/72
gayHaw = (gayHaw.orientation).value_counts()/66
gayBlack = (gayBlack.orientation).value_counts()/64
gayAsian = (gayAsian.orientation).value_counts()/72

straightAmIndian = (straightAmIndian.orientation).value_counts()/79
straightLatina = (straightLatina.orientation).value_counts()/74
straightBiRacial = (straightBiRacial.orientation).value_counts()/73
straightWhite = (straightWhite.orientation).value_counts()/72
straightHaw = (straightHaw.orientation).value_counts()/66
straightBlack = (straightBlack.orientation).value_counts()/64
straightAsian = (straightAsian.orientation).value_counts()/72

otherAmIndian = (otherAmIndian.orientation).value_counts()/79
otherLatina = (otherLatina.orientation).value_counts()/74
otherBiRacial = (otherBiRacial.orientation).value_counts()/73
otherWhite = (otherWhite.orientation).value_counts()/72
otherHaw = (otherHaw.orientation).value_counts()/66
otherBlack = (otherBlack.orientation).value_counts()/64
otherAsian = (otherAsian.orientation).value_counts()/72

biAmIndian = (biAmIndian.orientation).value_counts()/79
biLatina = (biLatina.orientation).value_counts()/74
biBiRacial = (biBiRacial.orientation).value_counts()/73
biWhite = (biWhite.orientation).value_counts()/72
biHaw = (biHaw.orientation).value_counts()/66
biBlack = (biBlack.orientation).value_counts()/64
biAsian = (biAsian.orientation).value_counts()/72

# %%
gayAmIndian 
gayLatina 
gayBiRacial 
gayWhite 
gayHaw 
gayBlack 
gayAsian 

straightAmIndian 
straightLatina 
straightBiRacial 
straightWhite 
straightHaw 
straightBlack 
straightAsian 

otherAmIndian 
otherLatina
otherBiRacial 
otherWhite 
otherHaw 
otherBlack 
otherAsian 

biAmIndian 
biLatina 
biBiRacial 
biWhite 
biHaw 
biBlack 
biAsian
# Out:
# Bisexual    0.277778
# Name: orientation, dtype: float64

# %%
import numpy as np 
from pandas import DataFrame
import seaborn as sns
# %matplotlib inline

Index= ['aaa', 'bbb', 'ccc', 'ddd', 'eee']
Cols = ['A', 'B', 'C', 'D']
df = DataFrame(abs(np.random.randn(5, 4)), index=Index, columns=Cols)

print(df)

sns.heatmap(df, annot=True)
# Out:
#             A         B         C         D
# aaa  0.898075  0.402676  0.169716  0.168066
# bbb  2.256898  1.881501  0.435095  1.363185
# ccc  1.017949  0.241634  0.596369  1.958244
# ddd  0.266765  1.108140  1.419417  0.526818
# eee  0.327638  0.582853  1.080377  0.598226
